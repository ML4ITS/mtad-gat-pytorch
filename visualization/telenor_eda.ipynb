# %% [markdown]
# ## Exploring The Telenor Telco Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import os
import pickle
from datetime import datetime
from sklearn.metrics import f1_score, precision_score, recall_score
import plotly as py
from plotly.offline import download_plotlyjs, init_notebook_mode
import plotly.graph_objs as go
import seaborn as sns
import cufflinks as cf
import glob
import sys
import json
from tqdm.notebook import tqdm
cf.go_offline()
init_notebook_mode;
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ### Loading the data

# %%
data_path = '../../Data/Data_DK/radio_kpis_sample.csv'
data_path = '../../Hackathon2021_Telenor/hackathon_kpis_anonymised.csv'
df = pd.read_csv(data_path)

# %% [markdown]
# ### Some info
# From below we see that we have 1042688 rows of data.
# From df.describe() we also see that most columns have missing values, and that all data is between 0 and 1.

# %%
print(df.shape)
df.head()
# Out:
# (1042688, 16)
#   cell_name                  timestamp  ho_failure_rate  num_voice_attempts  \
# 0    00_11Z  2020-04-09 15:00:00+00:00         0.333333            0.000927
# 1    00_11Z  2020-04-22 14:00:00+00:00         0.360000            0.017609
# 2    00_11Z  2020-05-08 21:00:00+00:00         0.333333            0.002780
# 3    00_11Z  2020-05-10 13:00:00+00:00         0.380952            0.012048
# 4    00_11Z  2020-05-12 03:00:00+00:00              NaN                 NaN
#
#    voice_drop_rate  num_data_attempts  voice_setup_failure_rate  \
# 0              0.0           0.004527                       0.0
# 1              0.0           0.012312                       0.0
# 2              0.0           0.008115                       0.0
# 3              0.0           0.004898                       0.0
# 4              NaN                NaN                       NaN
#
#    voice_tot_failure_rate  avail_period_duration  bandwidth  throughput_rate  \
# 0                     0.0                    1.0    0.49975         0.000195
# 1                     0.0                    1.0    0.49975         0.000197
# 2                     0.0                    1.0    0.49975         0.000196
# 3                     0.0                    1.0    0.49975         0.000116
# 4                     NaN                    1.0    0.49975              NaN
#
#    data_setup_failure_rate  data_drop_rate  data_tot_failure_rate  \
# 0                 0.000000        0.000731               0.000731
# 1                 0.001075        0.000269               0.000403
# 2                 0.000000        0.000000               0.000000
# 3                 0.000000        0.002027               0.002027
# 4                      NaN             NaN                    NaN
#
#    unavail_total_rate  unavail_unplan_rate
# 0            0.333364                  0.0
# 1            0.333364                  0.0
# 2            0.333364                  0.0
# 3            0.333364                  0.0
# 4            0.666728                  0.0

# %%
df.describe()
# Out:
#        ho_failure_rate  num_voice_attempts  voice_drop_rate  \
# count    469309.000000       912315.000000    630066.000000
# mean          0.340013            0.012314         0.000720
# std           0.042657            0.027938         0.010291
# min           0.000000            0.000000         0.000000
# 25%           0.333333            0.000000         0.000000
# 50%           0.333333            0.002780         0.000000
# 75%           0.333333            0.011121         0.000000
# max           1.000000            1.000000         1.000000
#
#        num_data_attempts  voice_setup_failure_rate  voice_tot_failure_rate  \
# count      912210.000000             630066.000000           630066.000000
# mean            0.020732                  0.000980                0.001046
# std             0.037992                  0.018921                0.012102
# min             0.000000                  0.000000                0.000000
# 25%             0.002528                  0.000000                0.000000
# 50%             0.007744                  0.000000                0.000000
# 75%             0.022664                  0.000000                0.000000
# max             1.000000                  1.000000                1.000000
#
#        avail_period_duration     bandwidth  throughput_rate  \
# count           1.042688e+06  1.042688e+06    811369.000000
# mean            9.990099e-01  3.435080e-01         0.000180
# std             2.345380e-02  3.452026e-01         0.001994
# min             0.000000e+00  0.000000e+00         0.000000
# 25%             1.000000e+00  9.954977e-02         0.000014
# 50%             1.000000e+00  9.954977e-02         0.000099
# 75%             1.000000e+00  4.997499e-01         0.000248
# max             1.000000e+00  1.000000e+00         1.000000
#
#        data_setup_failure_rate  data_drop_rate  data_tot_failure_rate  \
# count            895247.000000   895247.000000          895247.000000
# mean                  0.002646        0.000333               0.000664
# std                   0.019858        0.002291               0.003553
# min                   0.000000        0.000000               0.000000
# 25%                   0.000000        0.000000               0.000000
# 50%                   0.000000        0.000000               0.000067
# 75%                   0.001343        0.000226               0.000576
# max                   1.000000        1.000000               1.000000
#
#        unavail_total_rate  unavail_unplan_rate
# count        1.042688e+06         1.031935e+06
# mean         3.579869e-01         1.435138e-05
# std          8.600321e-02         1.056791e-03
# min          0.000000e+00         0.000000e+00
# 25%          3.333642e-01         0.000000e+00
# 50%          3.333642e-01         0.000000e+00
# 75%          3.333642e-01         0.000000e+00
# max          1.000000e+00         1.000000e+00

# %% [markdown]
# ### Print number of nans for each column

# %%
nan_values = df.isna().sum()
print(nan_values)
nan_columns = nan_values[nan_values > 0].index.tolist()
nan_columns
# Out:
# cell_name                        0
# timestamp                        0
# ho_failure_rate             573379
# num_voice_attempts          130373
# voice_drop_rate             412622
# num_data_attempts           130478
# voice_setup_failure_rate    412622
# voice_tot_failure_rate      412622
# avail_period_duration            0
# bandwidth                        0
# throughput_rate             231319
# data_setup_failure_rate     147441
# data_drop_rate              147441
# data_tot_failure_rate       147441
# unavail_total_rate               0
# unavail_unplan_rate          10753
# dtype: int64
# ['ho_failure_rate',
#  'num_voice_attempts',
#  'voice_drop_rate',
#  'num_data_attempts',
#  'voice_setup_failure_rate',
#  'voice_tot_failure_rate',
#  'throughput_rate',
#  'data_setup_failure_rate',
#  'data_drop_rate',
#  'data_tot_failure_rate',
#  'unavail_unplan_rate']

# %% [markdown]
# ### Sorting data after timestamp

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'])
df = df.sort_values(by=['timestamp'])
df.head()
# Out:
#        cell_name                 timestamp  ho_failure_rate  \
# 519830    22_21Q 2019-11-04 00:00:00+00:00              NaN
# 486561    02_31Q 2019-11-04 00:00:00+00:00              NaN
# 850004    25_11W 2019-11-04 00:00:00+00:00              NaN
# 116626    28_11Y 2019-11-04 00:00:00+00:00              NaN
# 144594    12_21W 2019-11-04 00:00:00+00:00              NaN
#
#         num_voice_attempts  voice_drop_rate  num_data_attempts  \
# 519830                 NaN              NaN                NaN
# 486561            0.000000              NaN           0.000781
# 850004                 NaN              NaN                NaN
# 116626            0.000000              NaN           0.000000
# 144594            0.013902              0.0           0.091727
#
#         voice_setup_failure_rate  voice_tot_failure_rate  \
# 519830                       NaN                     NaN
# 486561                       NaN                     NaN
# 850004                       NaN                     NaN
# 116626                       NaN                     NaN
# 144594                       0.0                     0.0
#
#         avail_period_duration  bandwidth  throughput_rate  \
# 519830                    1.0    0.09955              NaN
# 486561                    1.0    0.09955     2.322707e-08
# 850004                    1.0    1.00000              NaN
# 116626                    1.0    0.00000              NaN
# 144594                    1.0    1.00000     5.298183e-04
#
#         data_setup_failure_rate  data_drop_rate  data_tot_failure_rate  \
# 519830                      NaN             NaN                    NaN
# 486561                      0.0        0.002119               0.002119
# 850004                      NaN             NaN                    NaN
# 116626                      NaN             NaN                    NaN
# 144594                      0.0        0.000090               0.000090
#
#         unavail_total_rate  unavail_unplan_rate
# 519830            0.333364                  0.0
# 486561            0.333364                  0.0
# 850004            0.666728                  0.0
# 116626            0.666728                  NaN
# 144594            0.333364                  0.0

# %% [markdown]
# ### Checking the resolution
# From below we see that it is hourly, and only once is there a gap of more than an hour (2020-03-29).

# %%
grouped_df = df.groupby(['timestamp'])

for timestamp, group in grouped_df:
    t = timestamp
    break

for timestamp, group in grouped_df:
    next_t = timestamp
    td = next_t - t
    td_mins = int(td.total_seconds() / 60)
    if td_mins != 60:
        print(f'Time between {t} and {timestamp} is not 1 hour')
    t = next_t
# Out:
# Time between 2019-11-04 00:00:00+00:00 and 2019-11-04 00:00:00+00:00 is not 1 hour
# Time between 2020-03-29 01:00:00+00:00 and 2020-03-29 04:00:00+00:00 is not 1 hour

# %% [markdown]
# ### Checking number of cells that has data present for each timestamp

# %% [markdown]
# We see that the number of cells present varies a lot and flunctuates around ~100.

# %%
timestamps = []
num_cells_at_time = []
for timestamp, group in grouped_df:
    timestamps.append(timestamp)
    num_cells_at_time.append(len(group))

num_cell_df = pd.DataFrame({'timestamp': timestamps, 'num_cells': num_cells_at_time})
fig = px.line(num_cell_df, x="timestamp", y='num_cells', hover_data={"timestamp": "|%B %d. %H:%M, %Y"}, title='Number of cells for each timestamp')
fig.show()


plt.boxplot(num_cells_at_time);
plt.title('Boxplot with number of cells for each timestamp')
plt.ylabel('# of cells')
plt.xticks([], [])
plt.show()
# Out:
# <div>                            <div id="7bf8be3e-fe3e-46d2-8250-fd8041111c7b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7bf8be3e-fe3e-46d2-8250-fd8041111c7b")) {                    Plotly.newPlot(                        "7bf8be3e-fe3e-46d2-8250-fd8041111c7b",                        [{"customdata": [["2019-11-04T00:00:00+00:00"], ["2019-11-04T01:00:00+00:00"], ["2019-11-04T02:00:00+00:00"], ["2019-11-04T03:00:00+00:00"], ["2019-11-04T04:00:00+00:00"], ["2019-11-04T05:00:00+00:00"], ["2019-11-04T06:00:00+00:00"], ["2019-11-04T07:00:00+00:00"], ["2019-11-04T08:00:00+00:00"], ["2019-11-04T09:00:00+00:00"], ["2019-11-04T10:00:00+00:00"], ["2019-11-04T11:00:00+00:00"], ["2019-11-04T12:00:00+00:00"], ["2019-11-04T13:00:00+00:00"], ["2019-11-04T14:00:00+00:00"], ["2019-11-04T15:00:00+00:00"], ["2019-11-04T16:00:00+00:00"], ["2019-11-04T17:00:00+00:00"], ["2019-11-04T18:00:00+00:00"], ["2019-11-04T19:00:00+00:00"], ["2019-11-04T20:00:00+00:00"], ["2019-11-04T21:00:00+00:00"], ["2019-11-04T22:00:00+00:00"], ["2019-11-04T23:00:00+00:00"], ["2019-11-05T00:00:00+00:00"], ["2019-11-05T01:00:00+00:00"], ["2019-11-05T02:00:00+00:00"], ["2019-11-05T03:00:00+00:00"], ["2019-11-05T04:00:00+00:00"], ["2019-11-05T05:00:00+00:00"], ["2019-11-05T06:00:00+00:00"], ["2019-11-05T07:00:00+00:00"], ["2019-11-05T08:00:00+00:00"], ["2019-11-05T09:00:00+00:00"], ["2019-11-05T10:00:00+00:00"], ["2019-11-05T11:00:00+00:00"], ["2019-11-05T12:00:00+00:00"], ["2019-11-05T13:00:00+00:00"], ["2019-11-05T14:00:00+00:00"], ["2019-11-05T15:00:00+00:00"], ["2019-11-05T16:00:00+00:00"], ["2019-11-05T17:00:00+00:00"], ["2019-11-05T18:00:00+00:00"], ["2019-11-05T19:00:00+00:00"], ["2019-11-05T20:00:00+00:00"], ["2019-11-05T21:00:00+00:00"], ["2019-11-05T22:00:00+00:00"], ["2019-11-05T23:00:00+00:00"], ["2019-11-06T00:00:00+00:00"], ["2019-11-06T01:00:00+00:00"], ["2019-11-06T02:00:00+00:00"], ["2019-11-06T03:00:00+00:00"], ["2019-11-06T04:00:00+00:00"], ["2019-11-06T05:00:00+00:00"], ["2019-11-06T06:00:00+00:00"], ["2019-11-06T07:00:00+00:00"], ["2019-11-06T08:00:00+00:00"], ["2019-11-06T09:00:00+00:00"], ["2019-11-06T10:00:00+00:00"], ["2019-11-06T11:00:00+00:00"], ["2019-11-06T12:00:00+00:00"], ["2019-11-06T13:00:00+00:00"], ["2019-11-06T14:00:00+00:00"], ["2019-11-06T15:00:00+00:00"], ["2019-11-06T16:00:00+00:00"], ["2019-11-06T17:00:00+00:00"], ["2019-11-06T18:00:00+00:00"], ["2019-11-06T19:00:00+00:00"], ["2019-11-06T20:00:00+00:00"], ["2019-11-06T21:00:00+00:00"], ["2019-11-06T22:00:00+00:00"], ["2019-11-06T23:00:00+00:00"], ["2019-11-07T00:00:00+00:00"], ["2019-11-07T01:00:00+00:00"], ["2019-11-07T02:00:00+00:00"], ["2019-11-07T03:00:00+00:00"], ["2019-11-07T04:00:00+00:00"], ["2019-11-07T05:00:00+00:00"], ["2019-11-07T06:00:00+00:00"], ["2019-11-07T07:00:00+00:00"], ["2019-11-07T08:00:00+00:00"], ["2019-11-07T09:00:00+00:00"], ["2019-11-07T10:00:00+00:00"], ["2019-11-07T11:00:00+00:00"], ["2019-11-07T12:00:00+00:00"], ["2019-11-07T13:00:00+00:00"], ["2019-11-07T14:00:00+00:00"], ["2019-11-07T15:00:00+00:00"], ["2019-11-07T16:00:00+00:00"], ["2019-11-07T17:00:00+00:00"], ["2019-11-07T18:00:00+00:00"], ["2019-11-07T19:00:00+00:00"], ["2019-11-07T20:00:00+00:00"], ["2019-11-07T21:00:00+00:00"], ["2019-11-07T22:00:00+00:00"], ["2019-11-07T23:00:00+00:00"], ["2019-11-08T00:00:00+00:00"], ["2019-11-08T01:00:00+00:00"], ["2019-11-08T02:00:00+00:00"], ["2019-11-08T03:00:00+00:00"], ["2019-11-08T04:00:00+00:00"], ["2019-11-08T05:00:00+00:00"], ["2019-11-08T06:00:00+00:00"], ["2019-11-08T07:00:00+00:00"], ["2019-11-08T08:00:00+00:00"], ["2019-11-08T09:00:00+00:00"], ["2019-11-08T10:00:00+00:00"], ["2019-11-08T11:00:00+00:00"], ["2019-11-08T12:00:00+00:00"], ["2019-11-08T13:00:00+00:00"], ["2019-11-08T14:00:00+00:00"], ["2019-11-08 ...

# %% [markdown]
# ## Aggregating cells within same sector
#
# The cell_name is of the form 'XX_ija', where:
#
# - XX in {00,01,02,..,30} denotes the site the cell belongs to;
# - i in {1,2,3} denotes the sector the cell belongs to;
# - j in {1,2,...} denotes the carrier;
# - a in {'Z','X','Y','W','V','R','Q','P'} denotes the technology and frequency of the cell based on the table below.

# %%
df2 = df.copy()
df2['site'] = df2['cell_name'].apply(lambda s: int(s.split('_')[0]))
df2['sector'] = df2['cell_name'].apply(lambda s: int(s.split('_')[1][0]))
df2['carrier'] = df2['cell_name'].apply(lambda s: int(s.split('_')[1][1]))
df2['tech'] = df2['cell_name'].apply(lambda s: s.split('_')[1][2])
df2.head()
# Out:
#        cell_name                 timestamp  ho_failure_rate  \
# 519830    22_21Q 2019-11-04 00:00:00+00:00              NaN
# 486561    02_31Q 2019-11-04 00:00:00+00:00              NaN
# 850004    25_11W 2019-11-04 00:00:00+00:00              NaN
# 116626    28_11Y 2019-11-04 00:00:00+00:00              NaN
# 144594    12_21W 2019-11-04 00:00:00+00:00              NaN
#
#         num_voice_attempts  voice_drop_rate  num_data_attempts  \
# 519830                 NaN              NaN                NaN
# 486561            0.000000              NaN           0.000781
# 850004                 NaN              NaN                NaN
# 116626            0.000000              NaN           0.000000
# 144594            0.013902              0.0           0.091727
#
#         voice_setup_failure_rate  voice_tot_failure_rate  \
# 519830                       NaN                     NaN
# 486561                       NaN                     NaN
# 850004                       NaN                     NaN
# 116626                       NaN                     NaN
# 144594                       0.0                     0.0
#
#         avail_period_duration  bandwidth  throughput_rate  \
# 519830                    1.0    0.09955              NaN
# 486561                    1.0    0.09955     2.322707e-08
# 850004                    1.0    1.00000              NaN
# 116626                    1.0    0.00000              NaN
# 144594                    1.0    1.00000     5.298183e-04
#
#         data_setup_failure_rate  data_drop_rate  data_tot_failure_rate  \
# 519830                      NaN             NaN                    NaN
# 486561                      0.0        0.002119               0.002119
# 850004                      NaN             NaN                    NaN
# 116626                      NaN             NaN                    NaN
# 144594                      0.0        0.000090               0.000090
#
#         unavail_total_rate  unavail_unplan_rate  site  sector  carrier tech
# 519830            0.333364                  0.0    22       2        1    Q
# 486561            0.333364                  0.0     2       3        1    Q
# 850004            0.666728                  0.0    25       1        1    W
# 116626            0.666728                  NaN    28       1        1    Y
# 144594            0.333364                  0.0    12       2        1    W

# %% [markdown]
# ### Fill NaN using mean or median of column within same sector

# %%
agg_df = df2.copy()
for c in nan_columns:
    agg_df[c] = agg_df[c].fillna(agg_df.groupby(['timestamp', 'site', 'sector'])[c].transform('median'))
    agg_df[c] = agg_df[c].fillna(agg_df.groupby(['timestamp', 'site'])[c].transform('median'))
    agg_df[c] = agg_df[c].fillna(agg_df.groupby(['site', 'sector'])[c].transform('median'))
    agg_df[c] = agg_df[c].fillna(agg_df.groupby(['site'])[c].transform('median'))
    agg_df[c] = agg_df[c].fillna(agg_df[c].median())
    
print(agg_df.isna().sum())
agg_df.head()
# Out:
# cell_name                   0
# timestamp                   0
# ho_failure_rate             0
# num_voice_attempts          0
# voice_drop_rate             0
# num_data_attempts           0
# voice_setup_failure_rate    0
# voice_tot_failure_rate      0
# avail_period_duration       0
# bandwidth                   0
# throughput_rate             0
# data_setup_failure_rate     0
# data_drop_rate              0
# data_tot_failure_rate       0
# unavail_total_rate          0
# unavail_unplan_rate         0
# site                        0
# sector                      0
# carrier                     0
# tech                        0
# dtype: int64
#        cell_name                 timestamp  ho_failure_rate  \
# 519830    22_21Q 2019-11-04 00:00:00+00:00         0.333333
# 486561    02_31Q 2019-11-04 00:00:00+00:00         0.333333
# 850004    25_11W 2019-11-04 00:00:00+00:00         0.333333
# 116626    28_11Y 2019-11-04 00:00:00+00:00         0.333333
# 144594    12_21W 2019-11-04 00:00:00+00:00         0.333333
#
#         num_voice_attempts  voice_drop_rate  num_data_attempts  \
# 519830            0.000000              0.0           0.002092
# 486561            0.000000              0.0           0.000781
# 850004            0.000463              0.0           0.003905
# 116626            0.000000              0.0           0.000000
# 144594            0.013902              0.0           0.091727
#
#         voice_setup_failure_rate  voice_tot_failure_rate  \
# 519830                       0.0                     0.0
# 486561                       0.0                     0.0
# 850004                       0.0                     0.0
# 116626                       0.0                     0.0
# 144594                       0.0                     0.0
#
#         avail_period_duration  bandwidth  throughput_rate  \
# 519830                    1.0    0.09955     2.703543e-04
# 486561                    1.0    0.09955     2.322707e-08
# 850004                    1.0    1.00000     1.017473e-04
# 116626                    1.0    0.00000     1.010678e-04
# 144594                    1.0    1.00000     5.298183e-04
#
#         data_setup_failure_rate  data_drop_rate  data_tot_failure_rate  \
# 519830                      0.0        0.000000               0.000000
# 486561                      0.0        0.002119               0.002119
# 850004                      0.0        0.000000               0.000000
# 116626                      0.0        0.000000               0.000049
# 144594                      0.0        0.000090               0.000090
#
#         unavail_total_rate  unavail_unplan_rate  site  sector  carrier tech
# 519830            0.333364                  0.0    22       2        1    Q
# 486561            0.333364                  0.0     2       3        1    Q
# 850004            0.666728                  0.0    25       1        1    W
# 116626            0.666728                  0.0    28       1        1    Y
# 144594            0.333364                  0.0    12       2        1    W

# %% [markdown]
# ### Now aggregate across each sector

# %%
agg_df = agg_df.groupby(['timestamp', 'site', 'sector']).agg('sum').reset_index()
agg_df.head()
# Out:
#                   timestamp  site  sector  ho_failure_rate  \
# 0 2019-11-04 00:00:00+00:00     0       2         1.000000
# 1 2019-11-04 00:00:00+00:00     0       3         1.000000
# 2 2019-11-04 00:00:00+00:00     1       1         0.666667
# 3 2019-11-04 00:00:00+00:00     1       2         1.333333
# 4 2019-11-04 00:00:00+00:00     1       3         1.000000
#
#    num_voice_attempts  voice_drop_rate  num_data_attempts  \
# 0            0.038925              0.0           0.288526
# 1            0.005561              0.0           0.066482
# 2            0.001854              0.0           0.068468
# 3            0.018536              0.0           0.120626
# 4            0.000000              0.0           0.124108
#
#    voice_setup_failure_rate  voice_tot_failure_rate  avail_period_duration  \
# 0                       0.0                     0.0                    3.0
# 1                       0.0                     0.0                    3.0
# 2                       0.0                     0.0                    2.0
# 3                       0.0                     0.0                    4.0
# 4                       0.0                     0.0                    3.0
#
#    bandwidth  throughput_rate  data_setup_failure_rate  data_drop_rate  \
# 0   0.199100     5.922941e-07                 0.001588        0.000504
# 1   0.298649     9.412815e-08                 0.003584        0.000224
# 2   2.000000     7.049330e-04                 0.000536        0.000041
# 3   1.999500     1.409866e-03                 0.000268        0.000164
# 4   0.698849     8.014958e-04                 0.018134        0.000030
#
#    data_tot_failure_rate  unavail_total_rate  unavail_unplan_rate  carrier
# 0               0.000702            1.000093                  0.0        4
# 1               0.000672            1.000093                  0.0        4
# 2               0.000122            1.333457                  0.0        3
# 3               0.000197            1.666821                  0.0        5
# 4               0.002297            1.000093                  0.0        4

# %% [markdown]
# ### Visualizing the number of cells in each sector, for each site

# %%
plt.figure(figsize=(70, 10))
ax = sns.countplot(x="site", hue="sector", data=agg_df)
plt.legend(loc='upper right', fontsize=40)
ax.set_ylabel('# of cells', fontsize=50)
ax.xaxis.label.set_size(50)
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
plt.title('Number of cells within each sector, for each site', fontsize=70)
plt.show()

# %% [markdown]
# ### Visualizing data for one of the sectors

# %%
sector_df = agg_df[(agg_df['site'] == 1) & (agg_df['sector'] == 1)]
print(sector_df.shape)
sector_df.head()
# Out:
# (9327, 18)
#                     timestamp  site  sector  ho_failure_rate  \
# 2   2019-11-04 00:00:00+00:00     1       1         0.666667
# 60  2019-11-04 01:00:00+00:00     1       1         0.333333
# 113 2019-11-04 02:00:00+00:00     1       1         1.666667
# 169 2019-11-04 03:00:00+00:00     1       1         0.333333
# 231 2019-11-04 04:00:00+00:00     1       1         0.666667
#
#      num_voice_attempts  voice_drop_rate  num_data_attempts  \
# 2              0.001854              0.0           0.068468
# 60             0.000000              0.0           0.000361
# 113            0.000000              0.0           0.120918
# 169            0.000000              0.0           0.004792
# 231            0.000000              0.0           0.030686
#
#      voice_setup_failure_rate  voice_tot_failure_rate  avail_period_duration  \
# 2                         0.0                     0.0                    2.0
# 60                        0.0                     0.0                    1.0
# 113                       0.0                     0.0                    5.0
# 169                       0.0                     0.0                    1.0
# 231                       0.0                     0.0                    2.0
#
#      bandwidth  throughput_rate  data_setup_failure_rate  data_drop_rate  \
# 2     2.000000         0.000705                 0.000536        0.000041
# 60    0.099550         0.000089                 0.000000        0.000000
# 113   1.048024         0.000589                 0.000000        0.000000
# 169   0.249625         0.000079                 0.000000        0.000000
# 231   0.599300         0.000295                 0.000000        0.000000
#
#      data_tot_failure_rate  unavail_total_rate  unavail_unplan_rate  carrier
# 2                 0.000122            1.333457                  0.0        3
# 60                0.000000            0.333364                  0.0        2
# 113               0.000000            1.666821                  0.0        6
# 169               0.000000            0.333364                  0.0        1
# 231               0.000000            0.666728                  0.0        3

# %%
column = 'data_tot_failure_rate'
fig = px.line(sector_df, x="timestamp", y=column)
fig.show()
# Out:
# <div>                            <div id="3ad8dbd9-fc17-4229-83e7-e30380364dbf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3ad8dbd9-fc17-4229-83e7-e30380364dbf")) {                    Plotly.newPlot(                        "3ad8dbd9-fc17-4229-83e7-e30380364dbf",                        [{"hovertemplate": "timestamp=%{x}<br>data_tot_failure_rate=%{y}<extra></extra>", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "showlegend": false, "type": "scattergl", "x": ["2019-11-04T00:00:00+00:00", "2019-11-04T01:00:00+00:00", "2019-11-04T02:00:00+00:00", "2019-11-04T03:00:00+00:00", "2019-11-04T04:00:00+00:00", "2019-11-04T05:00:00+00:00", "2019-11-04T06:00:00+00:00", "2019-11-04T07:00:00+00:00", "2019-11-04T08:00:00+00:00", "2019-11-04T09:00:00+00:00", "2019-11-04T10:00:00+00:00", "2019-11-04T11:00:00+00:00", "2019-11-04T12:00:00+00:00", "2019-11-04T13:00:00+00:00", "2019-11-04T14:00:00+00:00", "2019-11-04T15:00:00+00:00", "2019-11-04T16:00:00+00:00", "2019-11-04T17:00:00+00:00", "2019-11-04T18:00:00+00:00", "2019-11-04T19:00:00+00:00", "2019-11-04T20:00:00+00:00", "2019-11-04T21:00:00+00:00", "2019-11-04T22:00:00+00:00", "2019-11-04T23:00:00+00:00", "2019-11-05T00:00:00+00:00", "2019-11-05T01:00:00+00:00", "2019-11-05T02:00:00+00:00", "2019-11-05T03:00:00+00:00", "2019-11-05T04:00:00+00:00", "2019-11-05T05:00:00+00:00", "2019-11-05T06:00:00+00:00", "2019-11-05T07:00:00+00:00", "2019-11-05T08:00:00+00:00", "2019-11-05T09:00:00+00:00", "2019-11-05T11:00:00+00:00", "2019-11-05T12:00:00+00:00", "2019-11-05T13:00:00+00:00", "2019-11-05T14:00:00+00:00", "2019-11-05T15:00:00+00:00", "2019-11-05T16:00:00+00:00", "2019-11-05T17:00:00+00:00", "2019-11-05T18:00:00+00:00", "2019-11-05T19:00:00+00:00", "2019-11-05T20:00:00+00:00", "2019-11-05T21:00:00+00:00", "2019-11-05T22:00:00+00:00", "2019-11-05T23:00:00+00:00", "2019-11-06T00:00:00+00:00", "2019-11-06T01:00:00+00:00", "2019-11-06T02:00:00+00:00", "2019-11-06T03:00:00+00:00", "2019-11-06T04:00:00+00:00", "2019-11-06T05:00:00+00:00", "2019-11-06T06:00:00+00:00", "2019-11-06T08:00:00+00:00", "2019-11-06T09:00:00+00:00", "2019-11-06T10:00:00+00:00", "2019-11-06T11:00:00+00:00", "2019-11-06T12:00:00+00:00", "2019-11-06T13:00:00+00:00", "2019-11-06T14:00:00+00:00", "2019-11-06T15:00:00+00:00", "2019-11-06T16:00:00+00:00", "2019-11-06T17:00:00+00:00", "2019-11-06T19:00:00+00:00", "2019-11-06T20:00:00+00:00", "2019-11-06T21:00:00+00:00", "2019-11-06T22:00:00+00:00", "2019-11-06T23:00:00+00:00", "2019-11-07T01:00:00+00:00", "2019-11-07T02:00:00+00:00", "2019-11-07T03:00:00+00:00", "2019-11-07T04:00:00+00:00", "2019-11-07T05:00:00+00:00", "2019-11-07T06:00:00+00:00", "2019-11-07T07:00:00+00:00", "2019-11-07T08:00:00+00:00", "2019-11-07T09:00:00+00:00", "2019-11-07T10:00:00+00:00", "2019-11-07T11:00:00+00:00", "2019-11-07T12:00:00+00:00", "2019-11-07T13:00:00+00:00", "2019-11-07T14:00:00+00:00", "2019-11-07T15:00:00+00:00", "2019-11-07T16:00:00+00:00", "2019-11-07T17:00:00+00:00", "2019-11-07T18:00:00+00:00", "2019-11-07T19:00:00+00:00", "2019-11-07T20:00:00+00:00", "2019-11-07T21:00:00+00:00", "2019-11-07T22:00:00+00:00", "2019-11-08T00:00:00+00:00", "2019-11-08T01:00:00+00:00", "2019-11-08T02:00:00+00:00", "2019-11-08T03:00:00+00:00", "2019-11-08T04:00:00+00:00", "2019-11-08T05:00:00+00:00", "2019-11-08T06:00:00+00:00", "2019-11-08T07:00:00+00:00", "2019-11-08T08:00:00+00:00", "2019-11-08T09:00:00+00:00", "2019-11-08T10:00:00+00:00", "2019-11-08T11:00:00+00:00", "2019-11-08T12:00:00+00:00", "2019-11-08T13:00:00+00:00", "2019-11-08T15:00:00+00:00", "2019-11-08T16:00:00+00:00", "2019-11-08T17:00:00+00:00", "2019-11-08T18:00:00+00:00", "2019-11-08T19:00:00+00:00", "2019-11-08T20:00:00+00:00", "2019-11-08T21:00:00+00:00 ...

# %%
sector_df_processed = sector_df.copy().drop(columns=['timestamp', 'site', 'sector', 'carrier'])

# %% [markdown]
# ###  Save data for each sector as separate numpy files

# %%
def get_sector_data(df, site, sector, test_split=0.3):
    data = df.copy()
    sector_data = data[(data['site'] == site) & (data['sector'] == sector)]
    sector_data = sector_data.sort_values(by=['timestamp'])
    sector_data_processed = sector_data.drop(columns=['timestamp', 'site', 'sector', 'carrier'])
    train_idx_stop = int(sector_data_processed.shape[0] * (1-test_split))
    train = sector_data_processed.iloc[:train_idx_stop, :]
    test = sector_data_processed.iloc[train_idx_stop:, :]
    return train, test

# %%
train_folder = '../datasets/telenor/train'
test_folder = '../datasets/telenor/test'
os.makedirs(train_folder, exist_ok=True)
os.makedirs(test_folder, exist_ok=True)

labeled_anomalies = {'chan_id': [],
                     'anomaly_sequences': [],
                     'class': [],
                     'num_values': []}

site_sector_combinations = agg_df[['site', 'sector']].value_counts().index.tolist()
for site, sector in sorted(site_sector_combinations):
    train, test = get_sector_data(agg_df, site, sector, test_split=0.3)
    np.save(f'{train_folder}/{site}-{sector}.npy', train)
    np.save(f'{test_folder}/{site}-{sector}.npy', test)
    
    labeled_anomalies['chan_id'].append(f'{site}-{sector}')
    labeled_anomalies['anomaly_sequences'].append([])
    labeled_anomalies['class'].append('')
    labeled_anomalies['num_values'].append(test.shape[0])

labeled_anomalies_df = pd.DataFrame(labeled_anomalies)
labeled_anomalies_df.to_csv('../datasets/telenor/labeled_anomalies.csv')
# Out:
# {'chan_id': ['0-1', '0-2', '0-3', '1-1', '1-2', '1-3', '2-1', '2-2', '2-3', '3-1', '3-2', '3-3', '4-1', '4-2', '4-3', '5-1', '5-2', '5-3', '6-1', '6-2', '6-3', '7-1', '7-2', '7-3', '8-1', '8-2', '8-3', '9-1', '9-2', '9-3', '10-1', '11-1', '11-2', '11-3', '12-1', '12-2', '12-3', '13-1', '13-2', '13-3', '14-1', '14-2', '14-3', '15-1', '15-2', '15-3', '16-1', '17-1', '17-2', '17-3', '18-1', '18-2', '18-3', '19-1', '19-2', '19-3', '20-1', '20-2', '20-3', '21-1', '21-2', '21-3', '22-1', '22-2', '22-3', '23-1', '23-2', '23-3', '24-1', '24-2', '24-3', '25-1', '25-2', '25-3', '26-1', '26-2', '26-3', '27-1', '28-1', '28-2', '28-3', '29-1', '30-1', '31-1', '32-1'], 'anomaly_sequences': [[], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []], 'class': ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', ''], 'num_values': [2578, 2560, 2576, 2799, 2791, 2789, 1820, 1805, 1807, 1829, 1811, 1841, 1815, 1829, 1842, 2497, 2491, 2500, 2502, 2506, 2487, 1798, 1826, 1805, 2520, 2522, 2514, 2382, 2353, 2338, 1383, 1816, 1829, 1815, 2779, 2779, 2781, 2748, 2737, 2746, 2792, 2787, 2802, 2550, 2530, 2510, 801, 1821, 1844, 1823, 1835, 1850, 1822, 2515, 2496, 2501, 1823, 1825, 1821, 1835, 1819, 1797, 2793, 2793, 2779, 2134, 2105, 2105, 1814, 1793, 1805, 2427, 2407, 2421, 1372, 1395, 1381, 1367, 805, 783, 781, 782, 25, 35, 5]}

# %%
train.head()
# Out:
#      ho_failure_rate  num_voice_attempts  voice_drop_rate  num_data_attempts  \
# 30          1.000000            0.002780              0.0           0.003455
# 90          1.000000            0.001390              0.0           0.017693
# 263         0.333333            0.000927              0.0           0.013040
# 325         0.333333            0.000000              0.0           0.004342
# 378         1.000000            0.002780              0.0           0.029111
#
#      voice_setup_failure_rate  voice_tot_failure_rate  avail_period_duration  \
# 30                        0.0                     0.0                    3.0
# 90                        0.0                     0.0                    3.0
# 263                       0.0                     0.0                    1.0
# 325                       0.0                     0.0                    1.0
# 378                       0.0                     0.0                    3.0
#
#      bandwidth  throughput_rate  data_setup_failure_rate  data_drop_rate  \
# 30    0.848924         0.000078                 0.000000        0.000000
# 90    1.249625         0.000183                 0.000000        0.001216
# 263   0.000000         0.000256                 0.003046        0.001650
# 325   1.000000         0.000259                 0.000000        0.000000
# 378   2.499750         0.000199                 0.028649        0.002149
#
#      data_tot_failure_rate  unavail_total_rate  unavail_unplan_rate
# 30                0.000000            1.333457                  0.0
# 90                0.001216            1.333549                  0.0
# 263               0.002030            0.333364                  0.0
# 325               0.000000            0.666728                  0.0
# 378               0.006447            2.000185                  0.0
